# %%
#Mysql in python
# !pip3 install mysql-connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 21.5 MB/s eta 0:00:00 MB/s eta 0:00:012
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'mysql-connector' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'mysql-connector'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp313-cp313-macosx_10_13_universal2.whl size=248037 sha256=18d8862bd1ab5e7b7355999db7870e1fab2d80f902d5b21a16c9e6929ea461a9
#   Stored in directory: /Users/priyeshshrestha/Library/Caches/pip/wheels/4e/c1/23/9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# Successfully built mysql-connector
# ...
#
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
#Connecting to mysql server and database
#Check user accounts in phpMyAdmin from xampp
database = mysql.connector.connect(
                host="localhost",
                user="root",
                password="")
                
db = database.cursor() #This holds the sql server session

db.execute("CREATE DATABASE pythans")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 11
#       4 database = mysql.connector.connect(
#       5                 host="localhost",
#       6                 user="root",
#       7                 password="")
#       9 db = database.cursor() #This holds the sql server session
# ---> 11 db.execute("CREATE DATABASE pythans")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/mysql/connector/cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
#Creating a table
database = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "",

    database = "PythonBroadway")
db = database.cursor()
db.execute("CREATE TABLE subject(id INT, name VARCHAR(255))") #To create table

# %%
#To select all data from table
sql = "SELECT * FROM Students"
db.execute(sql)
result = db.fetchall()
result
# Out:
# [(1, 'Ram', 90, 67, 87, 90, 87, 450, 84.0, 'A'),
#  (2, 'Jalan', 89, 89, 55, 57, 88, 399, 79.9, 'B'),
#  (3, 'Hari', 56, 77, 76, 88, 65, 72, 78.0, 'B'),
#  (5, 'Sita', 0, 0, 0, 0, 0, 0, 0.0, 'F'),
#  (8, 'Madan', 89, 90, 78, 67, 89, 399, 79.8, 'B')]

# %%
#To select specific data that meets conditions from table
sql = "SELECT * FROM Students WHERE grade = 'B' "
db.execute(sql)
result = db.fetchall()
result
# Out:
# [(2, 'Jalan', 89, 89, 55, 57, 88, 399, 79.9, 'B'),
#  (3, 'Hari', 56, 77, 76, 88, 65, 72, 78.0, 'B'),
#  (8, 'Madan', 89, 90, 78, 67, 89, 399, 79.8, 'B')]

# %%
#To select specific data that meets conditions from table
sql = "SELECT * FROM Students WHERE grade = 'B' and total >= 350 "
db.execute(sql)
result = db.fetchall() #When reading use fetch
result
# Out:
# [(2, 'Jalan', 89, 89, 55, 57, 88, 399, 79.9, 'B'),
#  (8, 'Madan', 89, 90, 78, 67, 89, 399, 79.8, 'B')]

# %%
#insert data
sql = """
        INSERT INTO Students(name, physics, chemistry, maths, english, nepali, total, percentage, grade)
        VALUES('Mahan',76,40,72,47,69,279,79.8,'B'); """
db.execute(sql)
database.commit() #database came from database = mysql.connector.connect()
print(db.rowcount,"Record Inserted.")
# Out:
# 1 Record Inserted.

# %%
#WAP to create data entry app to store data of multiple students in table
# WAP to create data entry app for multiple students

name = input("Enter Name: ")
physics = float(input("Physics marks: "))
chemistry = float(input("Chemistry marks: "))
maths = float(input("Maths marks: "))
english = float(input("English marks: "))
nepali = float(input("Nepali marks: "))
total = physics + chemistry + maths + english + nepali
percentage = total / 5
if percentage >= 80:
    grade = 'A'
elif percentage >= 60:
    grade = 'B'
elif percentage >= 50:
    grade = 'C'
elif per >= 40:
    grade = 'D'
else:
    grade = 'F'

print("The total marks = ", total)
print("The percentage = ",percentage)
print("The grade = ", grade)

sql = f"""
        INSERT INTO Students(name, physics, chemistry, maths, english, nepali, total, percentage, grade)
        VALUES('{name}',{physics},{chemistry},{maths},{english},{nepali},{total},{percentage},'{grade}'; """
db.execute(sql)
database.commit() #database came from database = mysql.connector.connect()
print(db.rowcount,"Record Inserted.")
# Out:
# Enter Name:  mohan
# Physics marks:  23
# Chemistry marks:  64
# Maths marks:  44
# English marks:  34
# Nepali marks:  75
# The total marks =  240.0
# The percentage =  48.0
# The grade =  D
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[20], line 30
#      25 print("The grade = ", grade)
#      27 sql = f"""
#      28         INSERT INTO Students(name, physics, chemistry, maths, english, nepali, total, percentage, grade)
#      29         VALUES('{name}',{physics},{chemistry},{maths},{english},{nepali},{total},{percentage},'{grade}'; """
# ---> 30 db.execute(sql)
#      31 database.commit() #database came from database = mysql.connector.connect()
#      32 print(db.rowcount,"Record Inserted.")
#
# ...
