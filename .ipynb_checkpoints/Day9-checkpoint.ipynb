# %%
#remove duplicate values
a = ['aNt', 'apple', 'apple', 'Ball', 'Orange', 'Zebra']
c = a.count("apple")
for i in range(c):
    a.remove("apple")

    print(a)
# Out:
# ['aNt', 'apple', 'Ball', 'Orange', 'Zebra']
# ['aNt', 'Ball', 'Orange', 'Zebra']

# %%
#findind index of duplicate values
a = ['aNt', 'apple', 'apple', 'Ball', 'Orange', 'Zebra', 'APPle']
search = "apple"
l = len(a)
for i in range(l):
    if a[i].lower() == search.lower():
        print (i)
# Out:
# 1
# 2
# 6

# %%
#converting to lower and appending
b = []
a = ['aNt', 'Apple', 'apple', 'Ball', 'Orange', 'Zebra', 'APPle']
for i in a:
    b.append(i.lower())

b
# Out:
# ['ant', 'apple', 'apple', 'ball', 'orange', 'zebra', 'apple']

# %%
#removing all 3 common elements with different cases (long way)
b = []
a = ['aNt', 'Apple', 'apple', 'Ball', 'Orange', 'Zebra', 'APPle']
search = 'apple'
for i in a:
    b.append(i.lower())

c = b.count('apple')
for i in range(c):
    b.remove('apple')

print(b)
# Out:
# ['ant', 'ball', 'orange', 'zebra']

# %%
#removing all 3 common elements with different cases (easy and short way)
#optimal way
b = []
a = ['aNt', 'Apple', 'apple', 'Ball', 'Orange', 'Zebra', 'APPle']
search = 'apple'
for i in a:
    if i.lower() != search.lower():
        b.append(i)

print(b)
# Out:
# ['aNt', 'Ball', 'Orange', 'Zebra']

# %%
#search same kind of value with different cases in list
#first block converting to lower case
a = ['aNt', 'Apple', 'apple', 'Ball', 'Orange', 'Zebra', 'APPle']
b = []
for i in a:
    b.append(i.lower())

#second block searching same kind of value
search = input("Enter search = ")
if search.lower() in b:
    print("Yes", b.count(search))
# Out:
# Enter search =  apple
# Yes 3
